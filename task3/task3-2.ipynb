# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')
df = df.set_index('PassengerId') #set passengerid as the new index 
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.groupby('Sex').agg('count')['Survived']
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
plt.title('')
plt.pie(x=np.array(df.groupby('Sex').agg('count')['Survived']),labels=['female','male'],autopct='%1.1f%%')
plt.legend(loc='upper left')
plt.title('Sex Pie')
# Out:
# Text(0.5, 1.0, 'Sex Pie')

# %%
df['Sex'] = df['Sex'].map({'male':1,'female':0})
sns.pairplot(data=df[['Age','Sex','Fare']])

# %%
sns.displot(data=df.Fare) 
plt.title('Fare Distribution')
# Out:
# Text(0.5, 1.0, 'Fare Distribution')

# %%
df.Survived.sum() #number of the survived
# Out:
# 342
